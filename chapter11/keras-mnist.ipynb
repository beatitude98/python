# %%
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import Adam
from keras.utils import to_categorical
import warnings

warnings.filterwarnings('ignore')  

(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
print(X_train.shape)
# Out:
# (60000, 28, 28)

# %%
X_train = X_train.reshape(60000, 28 * 28).astype('float32') / 255
X_test = X_test.reshape(10000, 28 * 28).astype('float64') / 255

#one-hot encoding으로 변환
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

model = Sequential()
model.add(Dense(512, input_dim=784, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 512)               401920
#
#  dense_4 (Dense)             (None, 512)               262656
#
#  dense_5 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 669706 (2.55 MB)
# Trainable params: 669706 (2.55 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics='accuracy')

model.fit(X_train, y_train, epochs=100, batch_size=200)

model.evaluate(X_test, y_test)
# Out:
# Epoch 1/100
# 300/300 [==============================] - 6s 19ms/step - loss: 0.2448 - accuracy: 0.9290
# Epoch 2/100
# 300/300 [==============================] - 5s 17ms/step - loss: 0.0845 - accuracy: 0.9737
# Epoch 3/100
# 300/300 [==============================] - 5s 17ms/step - loss: 0.0553 - accuracy: 0.9826
# Epoch 4/100
# 300/300 [==============================] - 5s 17ms/step - loss: 0.0354 - accuracy: 0.9889
# Epoch 5/100
# 300/300 [==============================] - 5s 16ms/step - loss: 0.0251 - accuracy: 0.9920
# Epoch 6/100
# 300/300 [==============================] - 5s 17ms/step - loss: 0.0187 - accuracy: 0.9940
# Epoch 7/100
# 300/300 [==============================] - 5s 17ms/step - loss: 0.0149 - accuracy: 0.9954
# Epoch 8/100
# 300/300 [==============================] - 5s 17ms/step - loss: 0.0182 - accuracy: 0.9941
# Epoch 9/100
# 300/300 [==============================] - 5s 17ms/step - loss: 0.0131 - accuracy: 0.9956
# Epoch 10/100
# 300/300 [==============================] - 5s 17ms/step - loss: 0.0136 - accuracy: 0.9952
# Epoch 11/100
# 300/300 [==============================] - 5s 17ms/step - loss: 0.0086 - accuracy: 0.9971
# Epoch 12/100
# 300/300 [==============================] - 5s 17ms/step - loss: 0.0082 - accuracy: 0.9974
# Epoch 13/100
# 300/300 [==============================] - 5s 16ms/step - loss: 0.0091 - accuracy: 0.9970
# Epoch 14/100
# 300/300 [==============================] - 7s 23ms/step - loss: 0.0094 - accuracy: 0.9969
# Epoch 15/100
# 300/300 [==============================] - 4s 12ms/step - loss: 0.0122 - accuracy: 0.9960
# Epoch 16/100
# 300/300 [==============================] - 4s 12ms/step - loss: 0.0067 - accuracy: 0.9978
# Epoch 17/100
# 300/300 [==============================] - 5s 15ms/step - loss: 0.0110 - accuracy: 0.9964
# Epoch 18/100
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0071 - accuracy: 0.9979
# Epoch 19/100
# 300/300 [==============================] - 4s 13ms/step - loss: 0.0035 - accuracy: 0.9991
# Epoch 20/100
# 300/300 [==============================] - 4s 13ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 21/100
# 300/300 [==============================] - 4s 13ms/step - loss: 0.0059 - accuracy: 0.9983
# Epoch 22/100
# 300/300 [==============================] - 4s 14ms/step - loss: 0.0109 - accuracy: 0.9964
# Epoch 23/100
# 300/300 [==============================] - 4s 13ms/step - loss: 0.0088 - accuracy: 0.9971
# Epoch 24/100
# 300/300 [==============================] - 5s 17ms/step - loss: 0.0051 - accuracy: 0.9984
# Epoch 25/100
# 300/300 [==============================] - 5s 17ms/step - loss: 0.0036 - accuracy: 0.9989
# Epoch 26/100
# 300/300 [==============================] - 5s 17ms/step - loss: 0.0028 - accuracy: 0.9991
# Epoch 27/100
# 300/300 [==============================] - 5s 17ms/step - loss: 0.0047 - accuracy: 0.9988
# Epoch 28/100
# 300/300 [==============================] - 5s 18ms/step - loss: 0.0135 - accuracy: 0.9958
# Epoch 29/100
# 300/300 [==============================] - 5s 17ms/step - loss: 0.0042 - accuracy: 0.9985
# Epoch 30/100
# 300/300 [==============================] - 5s 17ms/step - loss: 0.0015 - accuracy: 0.9996
# Epoch 31/100
# 300/300 [==============================] - 6s 18ms/step - loss: 8.9556e-04 - accuracy: 0.9998
# Epoch 32/100
# 300/300 [==============================] - 7s 22ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 33/100
# 300/300 [==============================] - 5s 18ms/step - loss: 0.0098 - accuracy: 0.9969
# Epoch 34/100
# 300/300 [==============================] - 7s 24ms/step - loss: 0.0057 - accuracy: 0.9983
# Epoch 35/100
# 300/300 [==============================] - 6s 22ms/step - loss: 0.0054 - accuracy: 0.9983
# Epoch 36/100
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0041 - accuracy: 0.9987
# Epoch 37/100
# 300/300 [==============================] - 6s 19ms/step - loss: 0.0075 - accuracy: 0.9980
# Epoch 38/100
# 300/300 [==============================] - 6s 20ms/step - loss: 0.0026 - accuracy: 0.9993
# Epoch 39/100
# 300/300 [==============================] - 9s 29ms/step - loss: 4.4413e-04 - accuracy: 0.9999
# Epoch 40/100
# 300/300 [==============================] - 6s 21ms/step - loss: 6.5393e-04 - accuracy: 0.9998
# Epoch 41/100
# 300/300 [==============================] - 7s 24ms/step - loss: 4.2136e-04 - accuracy: 0.9999
# Epoch 42/100
# 300/300 [==============================] - 7s 22ms/step - loss: 4.9765e-05 - accuracy: 1.0000
# Epoch 43/100
# 300/300 [==============================] - 6s 21ms/step - loss: 1.3390e-05 - accuracy: 1.0000
# Epoch 44/100
# 300/300 [==============================] - 4s 12ms/step - loss: 9.6181e-06 - accuracy: 1.0000
# Epoch 45/100
# 300/300 [==============================] - 5s 15ms/step - loss: 7.8199e-06 - accuracy: 1.0000
# Epoch 46/100
# 300/300 [==============================] - 7s 22ms/step - loss: 6.5421e-06 - accuracy: 1.0000
# Epoch 47/100
# 300/300 [==============================] - 6s 19ms/step - loss: 5.5459e-06 - accuracy: 1.0000
# Epoch 48/100
# 300/300 [==============================] - 4s 13ms/step - loss: 4.7398e-06 - accuracy: 1.0000
# Epoch 49/100
# 300/300 [==============================] - 6s 20ms/step - loss: 4.0684e-06 - accuracy: 1.0000
# Epoch 50/100
# 300/300 [==============================] - 5s 16ms/step - loss: 3.5049e-06 - accuracy: 1.0000
# Epoch 51/100
# 300/300 [==============================] - 5s 16ms/step - loss: 3.0271e-06 - accuracy: 1.0000
# Epoch 52/100
# 300/300 [==============================] - 5s 16ms/step - loss: 2.6029e-06 - accuracy: 1.0000
# Epoch 53/100
# 300/300 [==============================] - 5s 15ms/step - loss: 2.2410e-06 - accuracy: 1.0000
# Epoch 54/100
# 300/300 [==============================] - 5s 16ms/step - loss: 1.9203e-06 - accuracy: 1.0000
# Epoch 55/100
# 300/300 [==============================] - 5s 16ms/step - loss: 1.6266e-06 - accuracy: 1.0000
# Epoch 56/100
# 300/300 [==============================] - 5s 16ms/step - loss: 1.3658e-06 - accuracy: 1.0000
# Epoch 57/100
# 300/300 [==============================] - 5s 16ms/step - loss: 1.1315e-06 - accuracy: 1.0000
# Epoch 58/100
# 300/300 [==============================] - 5s 16ms/step - loss: 9.2591e-07 - accuracy: 1.0000
# Epoch 59/100
# 300/300 [==============================] - 5s 16ms/step - loss: 7.5085e-07 - accuracy: 1.0000
# Epoch 60/100
# 300/300 [==============================] - 5s 16ms/step - loss: 6.0190e-07 - accuracy: 1.0000
# Epoch 61/100
# 300/300 [==============================] - 5s 16ms/step - loss: 4.7919e-07 - accuracy: 1.0000
# Epoch 62/100
# 300/300 [==============================] - 5s 16ms/step - loss: 3.8384e-07 - accuracy: 1.0000
# Epoch 63/100
# 300/300 [==============================] - 5s 16ms/step - loss: 3.0669e-07 - accuracy: 1.0000
# Epoch 64/100
# 300/300 [==============================] - 5s 16ms/step - loss: 2.4761e-07 - accuracy: 1.0000
# Epoch 65/100
# 300/300 [==============================] - 5s 15ms/step - loss: 2.0184e-07 - accuracy: 1.0000
# Epoch 66/100
# 300/300 [==============================] - 5s 16ms/step - loss: 1.6532e-07 - accuracy: 1.0000
# Epoch 67/100
# 300/300 [==============================] - 5s 15ms/step - loss: 1.3672e-07 - accuracy: 1.0000
# Epoch 68/100
# 300/300 [==============================] - 5s 16ms/step - loss: 1.1468e-07 - accuracy: 1.0000
# Epoch 69/100
# 300/300 [==============================] - 5s 15ms/step - loss: 9.6499e-08 - accuracy: 1.0000
# Epoch 70/100
# 300/300 [==============================] - 5s 16ms/step - loss: 8.1652e-08 - accuracy: 1.0000
# Epoch 71/100
# 300/300 [==============================] - 5s 15ms/step - loss: 6.9807e-08 - accuracy: 1.0000
# Epoch 72/100
# 300/300 [==============================] - 5s 16ms/step - loss: 5.9835e-08 - accuracy: 1.0000
# Epoch 73/100
# 300/300 [==============================] - 5s 15ms/step - loss: 5.1681e-08 - accuracy: 1.0000
# Epoch 74/100
# 300/300 [==============================] - 5s 15ms/step - loss: 4.4916e-08 - accuracy: 1.0000
# Epoch 75/100
# 300/300 [==============================] - 5s 16ms/step - loss: 3.9365e-08 - accuracy: 1.0000
# Epoch 76/100
# 300/300 [==============================] - 5s 16ms/step - loss: 3.4426e-08 - accuracy: 1.0000
# Epoch 77/100
# 300/300 [==============================] - 5s 16ms/step - loss: 3.0353e-08 - accuracy: 1.0000
# Epoch 78/100
# 300/300 [==============================] - 5s 16ms/step - loss: 2.6848e-08 - accuracy: 1.0000
# Epoch 79/100
# 300/300 [==============================] - 5s 16ms/step - loss: 2.3679e-08 - accuracy: 1.0000
# Epoch 80/100
# 300/300 [==============================] - 5s 15ms/step - loss: 2.1114e-08 - accuracy: 1.0000
# Epoch 81/100
# 300/300 [==============================] - 5s 15ms/step - loss: 1.8684e-08 - accuracy: 1.0000
# Epoch 82/100
# 300/300 [==============================] - 5s 15ms/step - loss: 1.6600e-08 - accuracy: 1.0000
# Epoch 83/100
# 300/300 [==============================] - 5s 16ms/step - loss: 1.4818e-08 - accuracy: 1.0000
# Epoch 84/100
# 300/300 [==============================] - 5s 16ms/step - loss: 1.3365e-08 - accuracy: 1.0000
# Epoch 85/100
# 300/300 [==============================] - 5s 15ms/step - loss: 1.1893e-08 - accuracy: 1.0000
# Epoch 86/100
# 300/300 [==============================] - 5s 15ms/step - loss: 1.0721e-08 - accuracy: 1.0000
# Epoch 87/100
# 300/300 [==============================] - 5s 15ms/step - loss: 9.6460e-09 - accuracy: 1.0000
# Epoch 88/100
# 300/300 [==============================] - 5s 15ms/step - loss: 8.6486e-09 - accuracy: 1.0000
# Epoch 89/100
# 300/300 [==============================] - 5s 15ms/step - loss: 7.7665e-09 - accuracy: 1.0000
# Epoch 90/100
# 300/300 [==============================] - 5s 16ms/step - loss: 7.1029e-09 - accuracy: 1.0000
# Epoch 91/100
# 300/300 [==============================] - 5s 15ms/step - loss: 6.4095e-09 - accuracy: 1.0000
# Epoch 92/100
# 300/300 [==============================] - 4s 15ms/step - loss: 5.8472e-09 - accuracy: 1.0000
# Epoch 93/100
# 300/300 [==============================] - 5s 15ms/step - loss: 5.2432e-09 - accuracy: 1.0000
# Epoch 94/100
# 300/300 [==============================] - 5s 15ms/step - loss: 4.7962e-09 - accuracy: 1.0000
# Epoch 95/100
# 300/300 [==============================] - 5s 15ms/step - loss: 4.3790e-09 - accuracy: 1.0000
# Epoch 96/100
# 300/300 [==============================] - 5s 15ms/step - loss: 3.9717e-09 - accuracy: 1.0000
# Epoch 97/100
# 300/300 [==============================] - 4s 15ms/step - loss: 3.5981e-09 - accuracy: 1.0000
# Epoch 98/100
# 300/300 [==============================] - 5s 15ms/step - loss: 3.3100e-09 - accuracy: 1.0000
# Epoch 99/100
# 300/300 [==============================] - 4s 15ms/step - loss: 3.0001e-09 - accuracy: 1.0000
# Epoch 100/100
# 300/300 [==============================] - 5s 15ms/step - loss: 2.7776e-09 - accuracy: 1.0000
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1440 - accuracy: 0.9865
# [0.14404550194740295, 0.9865000247955322]
