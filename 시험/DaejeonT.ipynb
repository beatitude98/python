# %%
#문제 : 올해를 기준으로 대전의 지난 40년 간의 평균기온, 최저기온, 최고기온의 변화를 시각화하시오(꺽은선 그래프)

import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('daejeon_temp.csv', encoding='cp949')
df.head()
# Out:
#     지점 지점명    일시  평균기온(°C)  최저기온(°C)  최고기온(°C)
# 0  133  대전  1983      12.5     -14.9      35.5
# 1  133  대전  1984      11.9     -15.2      35.8
# 2  133  대전  1985      12.2     -14.9      35.4
# 3  133  대전  1986      11.8     -14.8      34.7
# 4  133  대전  1987      12.5     -14.8      33.5

# %%
df.describe()
# Out:
#           지점           일시   평균기온(°C)   최저기온(°C)   최고기온(°C)
# count   40.0    40.000000  40.000000  40.000000  40.000000
# mean   133.0  2002.500000  13.007500 -13.772500  34.945000
# std      0.0    11.690452   0.634636   2.114539   1.494769
# min    133.0  1983.000000  11.800000 -17.500000  32.200000
# 25%    133.0  1992.750000  12.500000 -15.200000  33.900000
# 50%    133.0  2002.500000  13.050000 -13.850000  34.750000
# 75%    133.0  2012.250000  13.425000 -12.300000  35.825000
# max    133.0  2022.000000  14.300000  -9.300000  39.400000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   지점        40 non-null     int64
#  1   지점명       40 non-null     object
#  2   일시        40 non-null     int64
#  3   평균기온(°C)  40 non-null     float64
#  4   최저기온(°C)  40 non-null     float64
#  5   최고기온(°C)  40 non-null     float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 2.0+ KB

# %%
df2 = df.bfill()
df2
# Out:
#      지점 지점명    일시  평균기온(°C)  최저기온(°C)  최고기온(°C)
# 0   133  대전  1983      12.5     -14.9      35.5
# 1   133  대전  1984      11.9     -15.2      35.8
# 2   133  대전  1985      12.2     -14.9      35.4
# 3   133  대전  1986      11.8     -14.8      34.7
# 4   133  대전  1987      12.5     -14.8      33.5
# 5   133  대전  1988      12.3     -12.0      35.3
# 6   133  대전  1989      13.1     -11.0      34.4
# 7   133  대전  1990      13.4     -16.2      36.7
# 8   133  대전  1991      12.6     -15.2      33.8
# 9   133  대전  1992      12.8      -9.6      34.1
# 10  133  대전  1993      12.3     -12.0      32.3
# 11  133  대전  1994      13.8     -13.2      37.7
# 12  133  대전  1995      12.3     -13.3      36.1
# 13  133  대전  1996      12.1     -14.2      35.6
# 14  133  대전  1997      12.8     -15.3      34.7
# 15  133  대전  1998      13.6     -13.4      34.2
# 16  133  대전  1999      13.0     -13.5      33.8
# 17  133  대전  2000      12.4     -12.4      33.9
# 18  133  대전  2001      13.1     -17.4      34.4
# ...

# %%
plt.rc('font', family='NanumGothic')
plt.figure(figsize=(15,8))
plt.plot(df2['일시'], df2['평균기온(°C)'], label='평균기온',c='g')
plt.plot(df2['일시'], df2['최고기온(°C)'], label='최고기온',c='r')
plt.plot(df2['일시'], df2['최저기온(°C)'], label='최저기온',c='b')
plt.xlabel('년도')
plt.ylabel('기온')
plt.legend()
plt.show()
# Out:
# /home/pc32/PycharmProjects/BasicPython/venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
