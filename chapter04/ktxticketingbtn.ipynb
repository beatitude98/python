# %%
import time

from selenium import webdriver
from selenium.webdriver import Keys
from selenium.webdriver.common.by import By

url = "https://www.letskorail.com/ebizprd/prdMain.do" # 크롤링 할 url 작성
driver = webdriver.Chrome()
driver.get(url)


time.sleep(1)

stop_btn = driver.find_element('xpath','/html/body/div/div[2]/p' )
stop_btn.click()

time.sleep(1)

stop_btn = driver.find_element('xpath','//*[@id="popCheck"]' )
stop_btn.click()

time.sleep(1)

stop_btn = driver.find_element('xpath','/html/body/div/div[2]/p/span[2]/a' )
stop_btn.click()

time.sleep(1)

# 시작
search_btn = driver.find_element('//*[@id="txtGoStart"]' )
search_btn.click() #출발지

time.sleep(1)

search_btn2 = driver.find_element('xpath','///html/body/div/div[2]/table/tbody/tr[3]/td[1]/a' )
search_btn2.click() #대전

time.sleep(1)

search_btn3 = driver.find_element('xpath','/html/body/div/div[2]/p/a' )
search_btn3.click() #대전확인버튼

time.sleep(1)

# 도착
search_btn4 = driver.find_element('xpath','//*[@id="res_cont_tab01"]/form/div/fieldset/ul[1]/li[2]/a/img' )
search_btn4.click() #돋보기버튼

time.sleep(1)

search_btn5 = driver.find_element('xpath','/html/body/div/div[2]/table/tbody/tr[1]/td[1]/a' )
search_btn5.click() #서울

time.sleep(1)

search_btn6 = driver.find_element('xpath','/html/body/div/div[2]/p/a' )
search_btn6.click() #서울확인버튼

time.sleep(1)

# 캘린더
callender_btn = driver.find_element('xpath','//*[@id="res_cont_tab01"]/form/div/fieldset/ul[2]/li[1]/a/img' )
callender_btn.click()

#정확한 날짜 9.28
date_btn = driver.find_element('xpath','//*[@id="d20230928"]' )
date_btn.click()

# 시간 2개
time_btn = driver.find_element('xpath','//*[@id="time"]' )
time_btn.click()

exacttime_btn = driver.find_element('xpath','//*[@id="time"]/option[7]' )
exacttime_btn.click()

# //*[@id="time"]/option[7]
# ~
# //*[@id="time"]/option[8]

# 인원그대로 에 승차권예매
purchase_btn = driver.find_element('xpath','//*[@id="res_cont_tab01"]/form/div/fieldset/p/a/img' )
purchase_btn.click()

modal_btn = driver.find_element('xpath','//*[@id="korail-alert"]/div[3]/button' )
modal_btn.click()




timesearch_btn = driver.find_element('xpath','//*[@id="center"]/div[3]/p/a/img' )
timesearch_btn.click()





# input_departure = driver.find_element("xpath", '//*[@id="txtGoStart"]')
# input_departure.send_keys("대전")
# 
# time.sleep(3.624153)
# input_arrive=driver.find_element("xpath", '//*[@id="get"]')
# input_arrive.send_keys("서울")
# time.sleep(3.624153)
# 
# time.sleep(1.753159)
# login_btn = driver.find_element(By.CSS_SELECTOR, ".confirm_btn > .submit")
# login_btn.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[22], line 14
#       9 driver.get(url)
#      12 time.sleep(1)
# ---> 14 stop_btn = driver.find_element('xpath','/html/body/div/div[2]/p' )
#      15 stop_btn.click()
#      17 time.sleep(1)
#
# File ~/PycharmProjects/BasicPython/venv/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:738, in WebDriver.find_element(self, by, value)
#     735     by = By.CSS_SELECTOR
#     736     value = f'[name="{value}"]'
# --> 738 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~/PycharmProjects/BasicPython/venv/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:344, in WebDriver.execute(self, driver_command, params)
#     342 response = self.command_executor.execute(driver_command, params)
#     343 if response:
# ...
